# %% [markdown]
# <a href="https://colab.research.google.com/github/LiviaEmi/Aula_mercado_funcao_if/blob/main/Tarefa_Pets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1 - criar uma lista com nome de 5 pets
lista_pets=['Meg',
            'Mingau',
            'Toby',
            'Shazam',
            "Princesa"]

#2 - criar uma função para exibir todos os pets
print (f'Pets: {lista_pets}')

#3 - criar uma função para cadastrar um novo pet
def ver_pets():
  print(f'Os pets que temos são: {lista_pets}')

def adicionar_pet():
  novo_pet = input('Informe o nome do pet: ')
  lista_pets.append(novo_pet)

#4 - criar um menu de opções para ver ou cadastrar pets
print('----Lista de Pets----')
print('Escolha a opção: ')
print('1 - ver pets')
print('2- cadastrar novo pet')
opcao=int(input('informe a opção desejada: '))

if opcao ==1:
  ver_pets()

elif opcao ==2:
  adicionar_pet()
  ver_pets()

else:
  print('Opção não encontrada')
# Out:
# Pets: ['Meg', 'Mingau', 'Toby', 'Shazam', 'Princesa']
# ----Lista de Pets----
# Escolha a opção:
# 1 - ver pets
# 2- cadastrar novo pet
# informe a opção desejada: 1
# Os pets que temos são: ['Meg', 'Mingau', 'Toby', 'Shazam', 'Princesa']
